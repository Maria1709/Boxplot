# %% [markdown]
# # Summary of the history of the box plot.

# %% [markdown]
# #### A box plot is a visual represenation of the statistical five number summary a the data set that is given.
# #### This includes
#   ####                    1.Minimum
#   ####                    2.First Quartile
#   ####                    3.Median (second quartile)
#   ####                   4. Third quartile
#   ####                   5. Maximum

# %% [markdown]
# #### Mathematican John Tukey was the first to introduce the Box and WHisker plot in 1969 to show a visual summery of the five number summary of any given data set. A man called Hadley Williams describes them, he says boxplots use robust summary statistics that are always located at  actual data points, are quickly computable and have no tuning parameters, and are usefull to compare distributions across groups.
# #### The chartio version is the closest to the original and is used to take a subset of data and quickly and visually show the  five number summary data set. But in the chartio version it has a tool tip is provided that shows all of the data points summarised in the visualisation.

# %% [markdown]
# ### Example of a boxplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

# generate random nos in 50s
spread = np.random.rand(50) * 120
# center boxplot 25 x 50
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 120 + 120
flier_low = np.random.rand(10) * -120
data = np.concatenate((spread, center, flier_high, flier_low))

# %%
# using basic plot
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xbbf88d0>],
#  'caps': [<matplotlib.lines.Line2D at 0xbc02438>,
#   <matplotlib.lines.Line2D at 0xbc02898>],
#  'fliers': [<matplotlib.lines.Line2D at 0xbc0b198>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xbc02cf8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xbbf8a58>,
#   <matplotlib.lines.Line2D at 0xbbf8f98>]}

# %%
plt.show()

# %%
# population = follwoing numbers of people
populationData = [8000000000, 12000000000, 6000000000, 75000000000, 1000000000, 120000000000, 150000000000]
#plot boxplot showing population data
plt.boxplot(populationData)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xbc81080>],
#  'caps': [<matplotlib.lines.Line2D at 0xbc81ba8>,
#   <matplotlib.lines.Line2D at 0xbc8a048>],
#  'fliers': [<matplotlib.lines.Line2D at 0xbc8a908>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xbc8a4a8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xbc81208>,
#   <matplotlib.lines.Line2D at 0xbc81748>]}

# %%
#show boxplot
plt.show()

# %%
populationData = [8000000000, 12000000000, 6000000000, 75000000000, 1000000000, 120000000000, 150000000000]
plt.boxplot(populationData)
# i now want to add title to top named population data
plt.title("population data")
# i now add a label to the y axes naming it ammount of people
plt.ylabel("Ammount of people")
plt.show()

# %%
# shows what directory i am in
pwd
# Out:
# 'C:\\Users\\Maria O Sullivan\\Desktop\\boxplot\\Boxplot'

# %%
# change directory
cd Boxplot
# Out:
# C:\Users\Maria O Sullivan\desktop\boxplot\Boxplot

# %%
# import pandas package as pd
import pandas as pd
# read in the csv file by calling it population
population = pd.read_csv('population data.csv')
#print population
population
# Out:
#       DATACODE                                            ED_NAME  \
# 0            1                                   001 Carlow Urban
# 1            2                                  002 Graigue Urban
# 2            3                                       003 Clonmore
# 3            4                                    004 Hacketstown
# 4            5                                    005 Haroldstown
# 5            6                                        006 Kineagh
# 6            7                                         007 Rahill
# 7            8                                      008 Rathvilly
# 8            9                                        009 Tiknock
# 9           10                                   010 Williamstown
# 10          11                                           011 Agha
# 11          12                                  012 Ballinacarrig
# 12          13                                   013 Ballintemple
# 13          14                                         014 Ballon
# 14          15                                     015 Ballyellin
# 15          16                                      016 Ballymoon
# 16          17                                         017 Borris
# 17          18                                    018 Burton Hall
# 18          19                                   019 Carlow Rural
# 19          20                                      020 Clogrenan
# 20          21                                      021 Clonegall
# 21          22                                        022 Corries
# 22          23                                      023 Cranemore
# 23          24                                        024 Fennagh
# 24          25                                      025 Garryhill
# 25          26                                     026 Grangeford
# 26          27                                      027 Johnstown
# 27          28                                     028 Kellistown
# 28          29                                       029 Kilbride
# 29          30                                     030 Killedmond
# ...        ...                                                ...
# 3376      3383                                     044 Lisnaveane
# 3377      3384                                       045 Newbliss
# 3378      3385                                    046 St. Tierney
# 3379      3386                                 047 Anketell Grove
# 3380      3387                                      048 Bellanode
# 3381      3388                                         049 Bragan
# 3382      3389                                        050 Caddagh
# 3383      3390                                    051 Castleshane
# 3384      3391                                         052 Clones
# 3385      3392                                     053 Clontibret
# 3386      3393                                     054 Derrygorry
# 3387      3394                                    055 Drumhillagh
# 3388      3395                                       056 Drumsnat
# 3389      3396                                        057 Emyvale
# 3390      3397                                          058 Enagh
# 3391      3398                                       059 Figullar
# 3392      3399                                      060 Glaslough
# 3393      3400                                     061 Killylough
# 3394      3401                                        062 Kilmore
# 3395      3402                                 063 Monaghan Rural
# 3396      3403                                    064 Rackwallace
# 3397      3404                                      065 Scotstown
# 3398      3405                                    066 Shanmullagh
# 3399      3406                                        067 Sheskin
# 3400      3407                                       068 Tedavnet
# 3401      3408                                       069 Tehallan
# 3402      3409                                    070 Tullycorbet
# 3403     25701   701 Ballynakill (part)(070)/Kilbarry (part)(074)
# 3404     27701   702 Bencorr(022)/Derrycunlagh(028)/Derrylea(027)
# 3405     28702  703 Aghalateeve(027)/Aghavoghill(029)/Aghanlis...
#
#              County NUTS_II      Region New Planning Region  POPULATION_02  \
# 0            Carlow      SE  South-East            Southern           4963
# 1            Carlow      SE  South-East            Southern           1702
# 2            Carlow      SE  South-East            Southern            461
# 3            Carlow      SE  South-East            Southern           1026
# 4            Carlow      SE  South-East            Southern            239
# 5            Carlow      SE  South-East            Southern            287
# 6            Carlow      SE  South-East            Southern            393
# 7            Carlow      SE  South-East            Southern            700
# 8            Carlow      SE  South-East            Southern            271
# 9            Carlow      SE  South-East            Southern            256
# 10           Carlow      SE  South-East            Southern            266
# 11           Carlow      SE  South-East            Southern            847
# 12           Carlow      SE  South-East            Southern            423
# 13           Carlow      SE  South-East            Southern            466
# 14           Carlow      SE  South-East            Southern            352
# 15           Carlow      SE  South-East            Southern            258
# 16           Carlow      SE  South-East            Southern            959
# 17           Carlow      SE  South-East            Southern            281
# 18           Carlow      SE  South-East            Southern          11238
# 19           Carlow      SE  South-East            Southern            687
# 20           Carlow      SE  South-East            Southern            808
# 21           Carlow      SE  South-East            Southern            482
# 22           Carlow      SE  South-East            Southern            724
# 23           Carlow      SE  South-East            Southern            473
# 24           Carlow      SE  South-East            Southern            594
# 25           Carlow      SE  South-East            Southern            283
# 26           Carlow      SE  South-East            Southern            499
# 27           Carlow      SE  South-East            Southern            864
# 28           Carlow      SE  South-East            Southern            354
# 29           Carlow      SE  South-East            Southern            367
# ...             ...     ...         ...                 ...            ...
# 3376       Monaghan     BMW      Border      North and West            385
# 3377       Monaghan     BMW      Border      North and West            666
# 3378       Monaghan     BMW      Border      North and West            409
# 3379       Monaghan     BMW      Border      North and West            954
# 3380       Monaghan     BMW      Border      North and West           1170
# 3381       Monaghan     BMW      Border      North and West            263
# 3382       Monaghan     BMW      Border      North and West            440
# 3383       Monaghan     BMW      Border      North and West            730
# 3384       Monaghan     BMW      Border      North and West            464
# 3385       Monaghan     BMW      Border      North and West            722
# 3386       Monaghan     BMW      Border      North and West            283
# 3387       Monaghan     BMW      Border      North and West            612
# 3388       Monaghan     BMW      Border      North and West            930
# 3389       Monaghan     BMW      Border      North and West           1091
# 3390       Monaghan     BMW      Border      North and West            449
# 3391       Monaghan     BMW      Border      North and West            413
# 3392       Monaghan     BMW      Border      North and West            726
# 3393       Monaghan     BMW      Border      North and West            558
# 3394       Monaghan     BMW      Border      North and West            539
# 3395       Monaghan     BMW      Border      North and West           4969
# 3396       Monaghan     BMW      Border      North and West            777
# 3397       Monaghan     BMW      Border      North and West            993
# 3398       Monaghan     BMW      Border      North and West            210
# 3399       Monaghan     BMW      Border      North and West            532
# 3400       Monaghan     BMW      Border      North and West            830
# 3401       Monaghan     BMW      Border      North and West            891
# 3402       Monaghan     BMW      Border      North and West            622
# 3403      Waterford      SE  South-East            Southern            372
# 3404  Galway County     BMW        West      North and West            478
# 3405        Leitrim     BMW      Border      North and West            431
#
#       POPULATION_06  POPULATION_11  POPULATION_16            ...              \
# 0              4605           4181           4573            ...
# 1              1524           1272           1432            ...
# 2               530            560            527            ...
# 3              1065           1091           1116            ...
# 4               267            259            291            ...
# 5               309            327            350            ...
# 6               585            662            727            ...
# 7               802            838            876            ...
# 8               331            338            331            ...
# 9               273            297            283            ...
# 10              322            382            394            ...
# 11              937           1005           1048            ...
# 12              480            559            566            ...
# 13              646            710            714            ...
# 14              375            427            425            ...
# 15              260            329            343            ...
# 16             1008           1041           1048            ...
# 17              368            465            526            ...
# 18            12548          13947          14544            ...
# 19              796            996           1042            ...
# 20              905            978            998            ...
# 21              504            532            539            ...
# 22              893           1067           1094            ...
# 23              516            736            783            ...
# 24              578            589            580            ...
# 25              324            424            464            ...
# 26              532            569            588            ...
# 27             1035           1001            974            ...
# 28              385            449            439            ...
# 29              409            424            408            ...
# ...             ...            ...            ...            ...
# 3376            428            395            397            ...
# 3377            741            798            819            ...
# 3378            416            395            397            ...
# 3379           1009           1129           1152            ...
# 3380           1359           1606           1504            ...
# 3381            290            298            311            ...
# 3382            469            495            497            ...
# 3383            876            966            986            ...
# 3384            462            472            451            ...
# 3385            700            701            757            ...
# 3386            273            272            283            ...
# 3387            630            691            668            ...
# 3388            937            982            998            ...
# 3389           1223           1230           1224            ...
# 3390            487            492            504            ...
# 3391            422            472            503            ...
# 3392            757            857            813            ...
# 3393            554            568            577            ...
# 3394            536            519            508            ...
# 3395           5611           6204           6214            ...
# 3396            794            903            909            ...
# 3397           1083           1155           1153            ...
# 3398            226            219            220            ...
# 3399            559            648            655            ...
# 3400            860            871            921            ...
# 3401            910            942            892            ...
# 3402            639            661            654            ...
# 3403            518            647            676            ...
# 3404            498            561            547            ...
# 3405            444            457            433            ...
#
#       VACANT_HOUSES_16  HOLIDAY_HOMES_11  HOLIDAY_HOMES_16  \
# 0                  356                 3                 1
# 1                  135                 7                 4
# 2                   37                 5                 9
# 3                   68                 5                 8
# 4                   10                 0                 0
# 5                   18                 1                 0
# 6                   44                 7                 5
# 7                   41                 8                 6
# 8                   15                 2                 1
# 9                   24                 2                 5
# 10                  10                 2                 2
# 11                  20                 1                 3
# 12                  17                 5                 8
# 13                  17                 1                 1
# 14                  13                 2                 1
# 15                  10                 0                 0
# 16                  73                13                13
# 17                  10                 0                 0
# 18                 312                 9                 8
# 19                  26                 1                 0
# 20                  56                23                28
# 21                  14                 3                 1
# 22                  49                 8                 4
# 23                  27                 3                 1
# 24                  38                 1                 3
# 25                  21                 2                 2
# 26                  11                 1                 0
# 27                  24                 2                 1
# 28                  18                 2                 2
# 29                  35                 9                18
# ...                ...               ...               ...
# 3376                26                 2                 1
# 3377                48                 8                 0
# 3378                15                 2                 2
# 3379                50                 4                 4
# 3380                53                 1                 5
# 3381                18                 2                 1
# 3382                25                 1                 2
# 3383                39                 1                 2
# 3384                25                 1                 4
# 3385                53                 1                 3
# 3386                10                 2                 0
# 3387                16                 0                 1
# 3388                40                 1                 0
# 3389                47                 3                 3
# 3390                19                 0                 2
# 3391                22                 4                 0
# 3392                80                 4                43
# 3393                22                 2                 1
# 3394                20                 2                 0
# 3395               188                 7                 7
# 3396                38                 0                 3
# 3397                38                 5                 3
# 3398                12                 2                 1
# 3399                45                 5                 5
# 3400                55                 1                 5
# 3401                34                 1                 0
# 3402                33                 1                 1
# 3403                11                 1                 3
# 3404               215               182               175
# 3405               107                38                42
#
#       VACANT_HOUSES_LESS_HOLIDAY_HOMES_11  \
# 0                                     503
# 1                                     179
# 2                                      19
# 3                                      75
# 4                                      12
# 5                                      17
# 6                                      39
# 7                                      32
# 8                                      16
# 9                                      21
# 10                                     12
# 11                                     20
# 12                                     20
# 13                                     31
# 14                                     11
# 15                                      7
# 16                                     55
# 17                                     11
# 18                                    462
# 19                                     36
# 20                                     53
# 21                                      9
# 22                                     36
# 23                                     34
# 24                                     49
# 25                                     40
# 26                                     14
# 27                                     28
# 28                                     11
# 29                                     36
# ...                                   ...
# 3376                                   16
# 3377                                   36
# 3378                                   12
# 3379                                   46
# 3380                                   44
# 3381                                   14
# 3382                                   27
# 3383                                   31
# 3384                                   26
# 3385                                   58
# 3386                                   16
# 3387                                   16
# 3388                                   59
# 3389                                   38
# 3390                                   18
# 3391                                   24
# 3392                                   64
# 3393                                   28
# 3394                                   10
# 3395                                  220
# 3396                                   37
# 3397                                   39
# 3398                                   18
# 3399                                   46
# 3400                                   60
# 3401                                   24
# 3402                                   31
# 3403                                   11
# 3404                                   37
# 3405                                   43
#
#       VACANT_HOUSES_LESS_HOLIDAY_HOMES_16  P_VACANT_HOUSES_11  \
# 0                                     355               21.16
# 1                                     131               25.00
# 2                                      28               11.01
# 3                                      60               16.99
# 4                                      10               11.32
# 5                                      18               12.86
# 6                                      39               15.75
# 7                                      35               11.02
# 8                                      14               13.33
# 9                                      19               17.83
# 10                                      8               10.00
# 11                                     17                5.60
# 12                                      9               11.74
# 13                                     16               12.12
# 14                                     12                8.33
# 15                                     10                5.56
# 16                                     60               15.45
# 17                                     10                6.21
# 18                                    304                8.32
# 19                                     26                9.97
# 20                                     28               18.05
# 21                                     13                6.28
# 22                                     45               10.33
# 23                                     26               12.46
# 24                                     35               20.58
# 25                                     19               21.00
# 26                                     11                7.14
# 27                                     23                8.15
# 28                                     16                7.98
# 29                                     17               24.32
# ...                                   ...                 ...
# 3376                                   25               11.61
# 3377                                   48               13.06
# 3378                                   13                9.86
# 3379                                   46               11.76
# 3380                                   48                7.84
# 3381                                   17               14.04
# 3382                                   23               14.81
# 3383                                   37                9.14
# 3384                                   21               13.78
# 3385                                   50               19.34
# 3386                                   10               15.65
# 3387                                   15                7.05
# 3388                                   40               14.74
# 3389                                   44                8.30
# 3390                                   17                9.89
# 3391                                   22               15.73
# 3392                                   37               17.94
# 3393                                   21               14.08
# 3394                                   20                5.83
# 3395                                  181                9.10
# 3396                                   35               11.21
# 3397                                   35               10.28
# 3398                                   11               20.83
# 3399                                   40               19.62
# 3400                                   50               16.80
# 3401                                   34                7.44
# 3402                                   32               12.75
# 3403                                    8                6.00
# 3404                                   40               57.33
# 3405                                   65               28.42
#
#       P_VACANT_HOUSES_16  PC_VACANT_HOUSES_02_16  P_VACANT_HOUSES_LESS_HH11  \
# 0                  14.37                  -29.42                      21.04
# 1                  17.53                  -26.82                      24.06
# 2                  16.37                   47.37                       8.72
# 3                  14.26                  -20.00                      15.92
# 4                   9.01                  -16.67                      11.32
# 5                  13.04                    5.88                      12.14
# 6                  14.67                    0.00                      13.36
# 7                  11.48                    9.38                       8.82
# 8                  11.45                  -12.50                      11.85
# 9                  18.32                   -9.52                      16.28
# 10                  7.25                  -33.33                       8.57
# 11                  4.95                  -15.00                       5.33
# 12                  7.91                  -55.00                       9.39
# 13                  6.56                  -48.39                      11.74
# 14                  7.93                    9.09                       7.05
# 15                  7.81                   42.86                       5.56
# 16                 16.33                    9.09                      12.50
# 17                  5.59                   -9.09                       6.21
# 18                  5.44                  -34.20                       8.16
# 19                  6.77                  -27.78                       9.70
# 20                 13.27                  -47.17                      12.59
# 21                  6.90                   44.44                       4.71
# 22                 11.16                   25.00                       8.45
# 23                  9.06                  -23.53                      11.45
# 24                 15.51                  -28.57                      20.16
# 25                 10.24                  -52.50                      20.00
# 26                  5.12                  -21.43                       6.67
# 27                  6.40                  -17.86                       7.61
# 28                 10.53                   45.45                       6.75
# 29                 19.13                  -52.78                      19.46
# ...                  ...                     ...                        ...
# 3376               15.66                   56.25                      10.32
# 3377               13.71                   33.33                      10.68
# 3378                9.87                    8.33                       8.45
# 3379               11.71                    0.00                      10.82
# 3380                8.67                    9.09                       7.67
# 3381               15.38                   21.43                      12.28
# 3382               12.95                  -14.81                      14.29
# 3383               10.43                   19.35                       8.86
# 3384               13.30                  -19.23                      13.27
# 3385               17.55                  -13.79                      19.02
# 3386                8.77                  -37.50                      13.91
# 3387                6.69                   -6.25                       7.05
# 3388                9.93                  -32.20                      14.50
# 3389                9.46                   15.79                       7.69
# 3390               10.11                   -5.56                       9.89
# 3391               12.09                   -8.33                      13.48
# 3392               20.25                  -42.19                      16.89
# 3393               10.14                  -25.00                      13.15
# 3394                9.43                  100.00                       4.85
# 3395                7.52                  -17.73                       8.82
# 3396               11.18                   -5.41                      11.21
# 3397                8.92                  -10.26                       9.11
# 3398               13.48                  -38.89                      18.75
# 3399               16.79                  -13.04                      17.69
# 3400               14.67                  -16.67                      16.53
# 3401               10.12                   41.67                       7.14
# 3402               12.99                    3.23                      12.35
# 3403                5.39                  -27.27                       5.50
# 3404               54.02                    8.11                       9.69
# 3405               36.64                   51.16                      15.09
#
#       P_VACANT_HOUSES_LESS_HH16
# 0                         14.33
# 1                         17.01
# 2                         12.39
# 3                         12.58
# 4                          9.01
# 5                         13.04
# 6                         13.00
# 7                          9.80
# 8                         10.69
# 9                         14.50
# 10                         5.80
# 11                         4.21
# 12                         4.19
# 13                         6.18
# 14                         7.32
# 15                         7.81
# 16                        13.42
# 17                         5.59
# 18                         5.30
# 19                         6.77
# 20                         6.64
# 21                         6.40
# 22                        10.25
# 23                         8.72
# 24                        14.29
# 25                         9.27
# 26                         5.12
# 27                         6.13
# 28                         9.36
# 29                         9.29
# ...                         ...
# 3376                      15.06
# 3377                      13.71
# 3378                       8.55
# 3379                      10.77
# 3380                       7.86
# 3381                      14.53
# 3382                      11.92
# 3383                       9.89
# 3384                      11.17
# 3385                      16.56
# 3386                       8.77
# 3387                       6.28
# 3388                       9.93
# 3389                       8.85
# 3390                       9.04
# 3391                      12.09
# 3392                       9.37
# 3393                       9.68
# 3394                       9.43
# 3395                       7.24
# 3396                      10.29
# 3397                       8.22
# 3398                      12.36
# 3399                      14.93
# 3400                      13.33
# 3401                      10.12
# 3402                      12.60
# 3403                       3.92
# 3404                      10.05
# 3405                      22.26
#
# [3406 rows x 26 columns]

# %%
#top five rows of data
population.head()
# Out:
#    DATACODE            ED_NAME  County NUTS_II      Region  \
# 0         1   001 Carlow Urban  Carlow      SE  South-East
# 1         2  002 Graigue Urban  Carlow      SE  South-East
# 2         3       003 Clonmore  Carlow      SE  South-East
# 3         4    004 Hacketstown  Carlow      SE  South-East
# 4         5    005 Haroldstown  Carlow      SE  South-East
#
#   New Planning Region  POPULATION_02  POPULATION_06  POPULATION_11  \
# 0            Southern           4963           4605           4181
# 1            Southern           1702           1524           1272
# 2            Southern            461            530            560
# 3            Southern           1026           1065           1091
# 4            Southern            239            267            259
#
#    POPULATION_16            ...              VACANT_HOUSES_16  \
# 0           4573            ...                           356
# 1           1432            ...                           135
# 2            527            ...                            37
# 3           1116            ...                            68
# 4            291            ...                            10
#
#    HOLIDAY_HOMES_11  HOLIDAY_HOMES_16  VACANT_HOUSES_LESS_HOLIDAY_HOMES_11  \
# 0                 3                 1                                  503
# 1                 7                 4                                  179
# 2                 5                 9                                   19
# 3                 5                 8                                   75
# 4                 0                 0                                   12
#
#    VACANT_HOUSES_LESS_HOLIDAY_HOMES_16  P_VACANT_HOUSES_11  \
# 0                                  355               21.16
# 1                                  131               25.00
# 2                                   28               11.01
# 3                                   60               16.99
# 4                                   10               11.32
#
#    P_VACANT_HOUSES_16  PC_VACANT_HOUSES_02_16  P_VACANT_HOUSES_LESS_HH11  \
# 0               14.37                  -29.42                      21.04
# 1               17.53                  -26.82                      24.06
# 2               16.37                   47.37                       8.72
# 3               14.26                  -20.00                      15.92
# 4                9.01                  -16.67                      11.32
#
#    P_VACANT_HOUSES_LESS_HH16
# 0                      14.33
# 1                      17.01
# 2                      12.39
# 3                      12.58
# 4                       9.01
#
# [5 rows x 26 columns]

# %%
# column names in the population data set
population.columns
# Out:
# Index(['DATACODE', 'ED_NAME', 'County', 'NUTS_II', 'Region',
#        'New Planning Region', 'POPULATION_02', 'POPULATION_06',
#        'POPULATION_11', 'POPULATION_16', 'PC_POP_02_16', 'PC_POP_06_16',
#        'PC_POP_11_16', 'HOUSING_STOCK_11', 'HOUSING_STOCK_16',
#        'VACANT_HOUSES_11', 'VACANT_HOUSES_16', 'HOLIDAY_HOMES_11',
#        'HOLIDAY_HOMES_16', 'VACANT_HOUSES_LESS_HOLIDAY_HOMES_11',
#        'VACANT_HOUSES_LESS_HOLIDAY_HOMES_16', 'P_VACANT_HOUSES_11',
#        'P_VACANT_HOUSES_16', 'PC_VACANT_HOUSES_02_16',
#        'P_VACANT_HOUSES_LESS_HH11', 'P_VACANT_HOUSES_LESS_HH16'],
#       dtype='object')

# %%
# plot a boxplot for the vacant houses column
plt.boxplot(population['P_VACANT_HOUSES_LESS_HH11'])
# title to be vacant houses less hh11
plt.title("P_VACANT_HOUSES_LESS_HH11")
# plot label on y axis is to be ammount of people
plt.ylabel("Ammount of people")
# show plot
plt.show()

# %%
#plot a boxplot for population column
plt.boxplot(population['POPULATION_02'])
# title to be population data
plt.title("population data")
# on y axis ammount of people
plt.ylabel("Ammount of people")
# show plot
plt.show()

# %%
# plot a boxplot for population 06 column
plt.boxplot(population['POPULATION_06'])
# title to be population 06
plt.title("P_VACANT_HOUSES_LESS_HH11")
# on y axis ammount of people
plt.ylabel("Ammount of people")  
# show plot
plt.show()

# %%
# in this one we are using nothced boxes 
fig2, ax2 = plt.subplots()
ax2.set_title('Notched boxes')
ax2.boxplot(data, notch=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xbbcca90>],
#  'caps': [<matplotlib.lines.Line2D at 0xbbd55f8>,
#   <matplotlib.lines.Line2D at 0xbbd5a58>],
#  'fliers': [<matplotlib.lines.Line2D at 0xbbde358>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xbbd5eb8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xbbccc18>,
#   <matplotlib.lines.Line2D at 0xbbd5198>]}

# %%
plt.show()

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
fig3, ax3 = plt.subplots()
ax3.set_title('Population')
ax3.boxplot(data, flierprops=green_diamond)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xbc20588>],
#  'caps': [<matplotlib.lines.Line2D at 0xbc28080>,
#   <matplotlib.lines.Line2D at 0xbc284e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0xbc28da0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xbc28940>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xbc20710>,
#   <matplotlib.lines.Line2D at 0xab71358>]}

# %%
plt.show()

# %%
fig4, ax4 = plt.subplots()
#hiding outlier points
ax4.set_title('POPULATION')
ax4.boxplot(data, showfliers=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x9152a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x91615c0>,
#   <matplotlib.lines.Line2D at 0x9161a20>],
#  'fliers': [],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x9161e80>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x9152be0>,
#   <matplotlib.lines.Line2D at 0x9161160>]}

# %%
plt.show()

# %%
u = u"""index,location,population
    Dec 14,Darogue,15.0
    Dec 14,Darogue,45.0
    Dec 14,Darogue,50.0
    Dec 14,Darogue,120.0
    Dec 14,Darogue,300.0"""
# using my address darogue in fake data
# importing io which is a web based platform that helps extract data from websites without having to write out any code
import io
# import pandas package as pd
import pandas as pd
# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
#data = string
data = io.StringIO(u)
# dataframe = read from csv file data sep and index is column 0
df = pd.read_csv(data, sep=",", index_col=0)
# boxplot of dataframe with population
plt.boxplot(df["population"])
## title is p vacant houses less h11
plt.title("P_VACANT_HOUSES_LESS_HH11")
#y label is ammount of people
plt.ylabel("Ammount of people")     
# show plot
plt.show()

# %% [markdown]
# ####  The five number summary the sample minimum, the lower quartile or the first quartile, the median, the upper quartile or the third quartile and the sample maximum.
# #### In the boxplot we draw a box from the first quartile and the third quartile, a vertical line goes throught the box at the median, then the whiskers go from each quartile to the minimum or maximum.

# %% [markdown]
# ### Example & Explanation of  Finding the five-number summary and of the term Quartile
# A sample of 101010 boxes of raisins has these weights (in grams):
# 252525, 282828, 292929, 292929, 303030, 343434, 353535, 353535, 373737, 383838
# Make a box plot of the data.
# Step 1: Order the data from smallest to largest.
# Our data is already in order.
# 252525, 282828, 292929, 292929, 303030, 343434, 353535, 353535, 373737, 383838
# Step 2: Find the median.
# The median is the mean of the middle two numbers:
# 252525, 282828, 292929, 292929, 30\large{30}30, 34\large{34}34, 353535, 353535, 373737, 383838
# 30+34/2​=32
# The median is 323232.
# Step 3: Find the quartiles.
# The first quartile is the median of the data points to the left of the median.
# 252525, 282828, 29\large{29}29, 292929, 303030
# Q1​=29
# The third quartile is the median of the data points to the right of the median.
# 343434, 353535, 35\large{35}35, 373737, 383838
# Q3=35Q_3=35Q3​=35
# Step 4: Complete the five-number summary by finding the min and the max.
# The min is the smallest data point, which is 252525.
# The max is the largest data point, which is 383838.
# The five-number summary is 252525, 292929, 323232, 353535, 383838.

# %% [markdown]
# The boxplot is used when we have large amounts of data that need organising and it visualises the outlier values. An example of situations it could be used in is in measuring weather and temperatures where the dataset would contain all the weather data inclduing the temperature from all the weather stations in a partcular country during a specific time period. They would use teh average daily temperature caculated over a 24 hour period in celsius. The boxplot would containg the the following data properties, Dimension which would measure both date and year ensuring date comes first is very important. The second data property is Measure to measure the temperature degrees in celsius. The boxplot will show a visualisation of the daily temperture measurements, in the mean temperature order, which is illustrated by the middle line in each box. The box then stretches form the first quartile to the third quartile adn the whiskers stretch 1.5 inter quartile ranges. There are also other values that lie outside the whiskers which are call outlier values.

# %% [markdown]
# ### Demonstration of a boxplot with simple data.

# %%
import pandas as pd
import numpy as np
# using numpy.random to generate nos form 10-5 using colsumns a,b,c,d,e. using 5 trials with 10 observations of a
# random variable
df = pd.DataFrame(np.random.rand(100, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box(grid='True')

# %%
plt.show()

# %%
# show plot with heading p vacant houses less hh11
plt.title("P_VACANT_HOUSES_LESS_HH11")
# y label has ammount of poeple as heading
plt.ylabel("Ammount of people")     
# show plot
plt.show()

# %%
import plotly
plotly.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-0731856489b5> in <module>()
# ----> 1 import plotly
#       2 plotly.__version__
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import plotly.plotly as py
import plotly.tools as tls

import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-a6f75acff5a4> in <module>()
# ----> 1 import plotly.plotly as py
#       2 import plotly.tools as tls
#       3
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# # Explanation of the term Percentile

# %% [markdown]
# #### A percentile is a number where a certain percentage of scores fall below that number. For example if your result is 67 out of 90 in a test, well that has no real meaning if you dont know what percentile you fall into. But if you know you are in the 90th percentile then you know you scored higher than 90 percent of the people who took the test. In personal experience percentile is used a lot in childrens developmental charts to show simply where your child is at towards the rest of the children in that paricular age range and so on giving a good indicator to how your child is developing towards the percentige of other children in regards to weight and height and so on.

# %% [markdown]
# ## Defintion 1 of Percentile

# %% [markdown]
# #### The nth percentile is the lowest score that is greater than a certain percentage (“n”) of the scores. In this example, our n is 25, so we’re looking for the lowest score that is greater than 25%.

# %% [markdown]
# # Defintion 2 of Percentile.

# %% [markdown]
# #### Definition 2: The nth percentile is the smallest score that is greater than or equal to a certain percentage of the scores. To rephrase this, it’s the percentage of data that falls at or below a certain observation. This is the definition used in AP statistics. In this example, the 25th percentile is the score that’s greater or equal to 25% of the scores.
#
# They may seem very similar, but they can lead to big differences in results, although they are both the 25th percentile rank. Take the following list of test scores, ordered by rank:
# Score
# 30
# 33
# 43
# 53
# 56
# 67
# 68
# 72

# %% [markdown]
# ### Rank
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# # Defintion 3 of Percentile

# %% [markdown]
# ####  Is a  weighted mean of the percentiles from the first two definitions.

# %% [markdown]
# # A Percentile range

# %% [markdown]
# #### A percentile range is the difference between two specified percentiles. these could theoretically be any two percentiles, but the 10-90 percentile range is the most common. To find the 10-90 percentile range:
#
#     Calculate the 10th percentile using the above steps.
#     Calculate the 90th percentile using the above steps.
#     Subtract Step 1 (the 10th percentile) from Step 2 (the 90th percentile).

# %% [markdown]
# # End
